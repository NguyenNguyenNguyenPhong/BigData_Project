# %%
# !pip install beautifulsoup4

# %%
import requests
import json
from bs4 import BeautifulSoup
x = requests.get('https://s.cafef.vn/bao-cao-tai-chinh/VCB/IncSta/2023/2/0/0/3/ket-qua-hoat-dong-kinh-doanh-ngan-hang-thuong-mai-co-phan-ngoai-thuong-viet-nam.chn')

htmldiv = BeautifulSoup(x.content)

tableData = htmldiv.find("table", {"id": "tableContent"})

cellHeaders = htmldiv.find("table", {"id": "tblGridData"}).find("tr").find_all("td")[1:5]
jsonTitle = []
jsonTitle.append("VCB_CrawData_KetQuaHoatDongKinhDoanh_LuyKe6Thang")
jsonHeader = []
for cellHeader in cellHeaders:
  jsonHeader.append(cellHeader.text.strip())

linesTable = tableData.find_all("tr")

jsonData = []

for lineTable in linesTable:
  cellTables = lineTable.find_all("td", limit=5)
  jsonData_line = []
  for cellTable in cellTables:
    jsonData_line.append(cellTable.text.strip())
  jsonData.append(jsonData_line)

jsonData.insert(0, [ *jsonTitle])
jsonData.insert(1, ["", *jsonHeader])

f = open("data.json", "w")
f.write(json.dumps(jsonData))
f.close()

f = open("data.json", "r")
jsonDataReaded = f.read()

jsonDataFormated = json.loads(jsonDataReaded)
formatted_data = [row for row in jsonDataFormated if any(row)]
formatted_data

# import pandas as pd
# df = pd.DataFrame(formatted_data)
# df
# Out:
# [['VCB_CrawData_KetQuaHoatDongKinhDoanh_LuyKe6Thang'],
#  ['',
#   'LK 6 tháng 2020(Đã soát xét)',
#   'LK 6 tháng 2021(Đã soát xét)',
#   'LK 6 tháng 2022(Đã soát xét)',
#   ''],
#  ['Thu nhập lãi ròng',
#   '17,111,640,000,000',
#   '21,177,991,000,000',
#   '24,773,058,000,000',
#   ''],
#  ['Thu nhập lãi và các khoản thu nhập tương tự',
#   '34,938,760,000,000',
#   '35,042,744,000,000',
#   '40,009,184,000,000',
#   ''],
#  ['Chi phí lãi và các khoản chi phí tương tự',
#   '17,827,120,000,000',
#   '13,864,753,000,000',
#   '15,236,126,000,000',
#   ''],
#  ['Lãi/lỗ ròng từ hoạt động dịch vụ',
#   '2,283,000,000,000',
#   '3,866,250,000,000',
#   '3,405,457,000,000',
#   ''],
#  ['Thu nhập từ hoạt động dịch vụ',
#   '4,116,301,000,000',
#   '5,799,748,000,000',
#   '5,702,775,000,000',
#   ''],
#  ['Chi phí hoạt động dịch vụ',
#   '1,833,301,000,000',
#   '1,933,498,000,000',
#   '2,297,318,000,000',
#   ''],
#  ['Lãi/lỗ ròng từ hoạt động kinh doanh ngoại hối và vàng',
#   '1,928,598,000,000',
#   '2,028,608,000,000',
#   '2,993,580,000,000',
#   ''],
#  ['Lãi/lỗ thuần từ mua bán chứng khoán kinh doanh',
#   '-21,084,000,000',
#   '90,149,000,000',
#   '35,153,000,000',
#   ''],
#  ['Lãi/ lỗ thuần từ mua bán chứng khoán đầu tư', '', '', '84,715,000,000', ''],
#  ['Lãi thuần từ hoạt động khác',
#   '1,325,104,000,000',
#   '1,371,912,000,000',
#   '1,364,899,000,000',
#   ''],
#  ['Thu nhập hoạt động khác',
#   '1,611,586,000,000',
#   '1,642,003,000,000',
#   '1,589,799,000,000',
#   ''],
#  ['Chi phí hoạt động khác',
#   '286,482,000,000',
#   '270,091,000,000',
#   '224,900,000,000',
#   ''],
#  ['Thu nhập từ góp vốn, mua cổ phần',
#   '391,783,000,000',
#   '53,987,000,000',
#   '48,840,000,000',
#   ''],
#  ['Tổng thu nhập kinh doanh',
#   '23,019,041,000,000',
#   '28,588,897,000,000',
#   '32,705,702,000,000',
#   ''],
#  ['Lãi/ lỗ trong công ty liên kết, liên doanh', '', '', '', ''],
#  ['Chi phí hoạt động',
#   '8,028,309,000,000',
#   '9,515,403,000,000',
#   '10,324,968,000,000',
#   ''],
#  ['Chi phí nhân viên', '', '', '', ''],
#  ['Chi phí khấu hao', '', '', '', ''],
#  ['Chi phí hoạt động khác', '', '', '', ''],
#  ['Lợi nhuận ròng từ hoạt động kinh doanh trước chi phí dự phòng',
#   '14,990,732,000,000',
#   '19,073,494,000,000',
#   '22,380,734,000,000',
#   ''],
#  ['Chi phí dự phòng', '', '', '', ''],
#  ['Chi phí dự phòng rủi ro tín dụng',
#   '4,008,666,000,000',
#   '5,500,066,000,000',
#   '5,007,391,000,000',
#   ''],
#  ['Các khoản xử lý theo đề tài cấu trúc Ngân hàng', '', '', '', ''],
#  ['Dự phòng chung cho các khoản cam kết và nợ tiềm tàng', '', '', '', ''],
#  ['Dự phòng giảm giá chứng khoán', '', '', '', ''],
#  ['Thu hồi nợ đã xử lý bằng nguồn dự phòng', '', '', '', ''],
#  ['Tổng lợi nhuận kế toán',
#   '10,982,066,000,000',
#   '13,573,428,000,000',
#   '17,373,343,000,000',
#   ''],
#  ['Thu nhập từ các khoản nợ khó đòi', '', '', '', ''],
#  ['Lợi nhuận được hưởng từ các công ty liên kết và liên doanh',
#   '',
#   '',
#   '',
#   ''],
#  ['Tổng lợi nhuận trước thuế',
#   '10,982,066,000,000',
#   '13,573,428,000,000',
#   '17,373,343,000,000',
#   ''],
#  ['Chi phí thuế TNDN',
#   '1,785,075,000,000',
#   '2,701,179,000,000',
#   '3,464,754,000,000',
#   ''],
#  ['Chi phí thuế hiện hành', '', '', '', ''],
#  ['Chi phí thuế hoãn lại',
#   '398,722,000,000',
#   '53,000,000',
#   '-768,000,000',
#   ''],
#  ['Lợi nhuận sau thuế',
#   '8,798,269,000,000',
#   '10,872,196,000,000',
#   '13,909,357,000,000',
#   ''],
#  ['Lợi ích của cổ đông thiểu số',
#   '10,015,000,000',
#   '9,513,000,000',
#   '10,219,000,000',
#   ''],
#  ['Lợi nhuận sau thuế của cổ đông công ty mẹ',
#   '8,788,254,000,000',
#   '10,862,683,000,000',
#   '13,899,138,000,000',
#   ''],
#  ['Lãi cơ bản trên cổ phiếu', '2,370', '2,929', '2,937', ''],
#  ['Lãi suy giảm trên cổ phiếu', '', '', '', '']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(formatted_data)
df.head(20)
# Out:
#                                                     0  \
# 0    VCB_CrawData_KetQuaHoatDongKinhDoanh_LuyKe6Thang
# 1
# 2                                   Thu nhập lãi ròng
# 3         Thu nhập lãi và các khoản thu nhập tương tự
# 4           Chi phí lãi và các khoản chi phí tương tự
# 5                    Lãi/lỗ ròng từ hoạt động dịch vụ
# 6                       Thu nhập từ hoạt động dịch vụ
# 7                           Chi phí hoạt động dịch vụ
# 8   Lãi/lỗ ròng từ hoạt động kinh doanh ngoại hối ...
# 9      Lãi/lỗ thuần từ mua bán chứng khoán kinh doanh
# 10        Lãi/ lỗ thuần từ mua bán chứng khoán đầu tư
# 11                        Lãi thuần từ hoạt động khác
# 12                            Thu nhập hoạt động khác
# 13                             Chi phí hoạt động khác
# 14                   Thu nhập từ góp vốn, mua cổ phần
# 15                           Tổng thu nhập kinh doanh
# 16         Lãi/ lỗ trong công ty liên kết, liên doanh
# 17                                  Chi phí hoạt động
# 18                                  Chi phí nhân viên
# 19                                   Chi phí khấu hao
#
#                                1                             2  \
# 0                           None                          None
# 1   LK 6 tháng 2020(Đã soát xét)  LK 6 tháng 2021(Đã soát xét)
# 2             17,111,640,000,000            21,177,991,000,000
# 3             34,938,760,000,000            35,042,744,000,000
# 4             17,827,120,000,000            13,864,753,000,000
# 5              2,283,000,000,000             3,866,250,000,000
# 6              4,116,301,000,000             5,799,748,000,000
# 7              1,833,301,000,000             1,933,498,000,000
# 8              1,928,598,000,000             2,028,608,000,000
# 9                -21,084,000,000                90,149,000,000
# 10
# 11             1,325,104,000,000             1,371,912,000,000
# 12             1,611,586,000,000             1,642,003,000,000
# 13               286,482,000,000               270,091,000,000
# 14               391,783,000,000                53,987,000,000
# 15            23,019,041,000,000            28,588,897,000,000
# 16
# 17             8,028,309,000,000             9,515,403,000,000
# 18
# 19
#
#                                3     4
# 0                           None  None
# 1   LK 6 tháng 2022(Đã soát xét)
# 2             24,773,058,000,000
# 3             40,009,184,000,000
# 4             15,236,126,000,000
# 5              3,405,457,000,000
# 6              5,702,775,000,000
# 7              2,297,318,000,000
# 8              2,993,580,000,000
# 9                 35,153,000,000
# 10                84,715,000,000
# 11             1,364,899,000,000
# 12             1,589,799,000,000
# 13               224,900,000,000
# 14                48,840,000,000
# 15            32,705,702,000,000
# 16
# 17            10,324,968,000,000
# 18
# 19
