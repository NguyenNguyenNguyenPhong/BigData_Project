# %%
# !pip install beautifulsoup4

# %%
import requests
import json
from bs4 import BeautifulSoup
x = requests.get('https://s.cafef.vn/bao-cao-tai-chinh/VCB/CashFlowDirect/2023/2/0/0/luu-chuyen-tien-te-gian-tiep-ngan-hang-thuong-mai-co-phan-ngoai-thuong-viet-nam.chn')

htmldiv = BeautifulSoup(x.content)

tableData = htmldiv.find("table", {"id": "tableContent"})

cellHeaders = htmldiv.find("table", {"id": "tblGridData"}).find("tr").find_all("td")[1:5]
jsonTitle = []
jsonTitle.append("VCB_CrawData_Lưu_Chuyển _Tiền_Tệ_Trực_Tiếp_Theo_Quý")
jsonHeader = []
for cellHeader in cellHeaders:
  jsonHeader.append(cellHeader.text.strip())

linesTable = tableData.find_all("tr")

jsonData = []

for lineTable in linesTable:
  cellTables = lineTable.find_all("td", limit=5)
  jsonData_line = []
  for cellTable in cellTables:
    jsonData_line.append(cellTable.text.strip())
  jsonData.append(jsonData_line)

jsonData.insert(0, [ *jsonTitle])
jsonData.insert(1, ["", *jsonHeader])

f = open("data.json", "w")
f.write(json.dumps(jsonData))
f.close()

f = open("data.json", "r")
jsonDataReaded = f.read()

jsonDataFormated = json.loads(jsonDataReaded)
formatted_data = [row for row in jsonDataFormated if any(row)]
formatted_data

# import pandas as pd
# df = pd.DataFrame(formatted_data)
# df
# Out:
# [['VCB_CrawData_Lưu_Chuyển _Tiền_Tệ_Trực_Tiếp_Theo_Quý'],
#  ['', 'Quý 3-2022', 'Quý 4-2022', 'Quý 1-2023', 'Quý 2-2023'],
#  ['I. Lưu chuyển tiền từ hoạt động kinh doanh', '', '', '', ''],
#  ['1. Thu nhập lãi và các khoản thu nhập tương tự đạt được',
#   '61,693,757,000,000',
#   '86,066,830,000,000',
#   '26,870,255,000,000',
#   ''],
#  ['2. Chi phí lãi và các chi phí tương tự đã trả',
#   '-20,664,896,000,000',
#   '-31,709,129,000,000',
#   '-10,245,350,000,000',
#   ''],
#  ['3. Thu nhập từ hoạt động dịch vụ nhận được',
#   '3,668,176,000,000',
#   '5,159,968,000,000',
#   '1,036,571,000,000',
#   ''],
#  ['4. Chênh lệch số tiền thực thu / (thực chi) từ hoạt động kinh doanh (ngoại tệ, vàng bạc, chứng khoán)',
#   '4,800,414,000,000',
#   '5,975,176,000,000',
#   '1,661,244,000,000',
#   ''],
#  ['5. Thu nhập thuần từ chứng khoán kinh doanh và chứng khoán sẵn sàng để bán',
#   '',
#   '',
#   '',
#   ''],
#  ['5. Thu nhập / (chi phí) khác',
#   '-211,915,000,000',
#   '-351,732,000,000',
#   '684,356,000,000',
#   ''],
#  ['6. Tiền thu từ các khoản nợ đã được xử lý xóa, bù đắp bằng nguồn dự phòng rủi ro',
#   '1,959,262,000,000',
#   '2,394,744,000,000',
#   '396,375,000,000',
#   ''],
#  ['6. Tiền chi trả cho nhân viên và hoạt động quản lý, công vụ',
#   '-12,755,544,000,000',
#   '-19,844,137,000,000',
#   '-5,387,579,000,000',
#   ''],
#  ['7. Tiền thuế thu nhập thực nộp trong kỳ',
#   '-3,933,379,000,000',
#   '-3,976,079,000,000',
#   '-5,577,486,000,000',
#   ''],
#  ['Lưu chuyển tiền thuần từ hoạt động kinh doanh trước những thay đổi của tài sản và công nợ hoạt động',
#   '34,555,875,000,000',
#   '43,715,641,000,000',
#   '9,438,386,000,000',
#   ''],
#  ['Thay đổi tài sản hoạt động', '', '', '', ''],
#  ['8. (Tăng) / giảm tiền, vàng gửi và cho vay các tổ chức tín dụng khác',
#   '-11,695,778,000,000',
#   '-15,019,465,000,000',
#   '17,257,309,000,000',
#   ''],
#  ['9. (Tăng) / giảm về kinh doanh chứng khoán',
#   '3,102,847,000,000',
#   '5,431,755,000,000',
#   '-8,025,946,000,000',
#   ''],
#  ['10. (Tăng) / giảm các công cụ tài chính phái sinh và các khoản nợ tài chính khác',
#   '303,202,000,000',
#   '146,687,000,000',
#   '-68,110,000,000',
#   ''],
#  ['11. (Tăng) / giảm các khoản cho vay khách hàng',
#   '-169,394,046,000,000',
#   '-184,316,295,000,000',
#   '-29,014,714,000,000',
#   ''],
#  ['11. Giảm nguồn dự phòng để bù đắp tổn thất các khoản (tín dung, chứng khoán, đầu tư dài hạn)',
#   '-297,256,000,000',
#   '-3,530,346,000,000',
#   '-29,914,000,000',
#   ''],
#  ['12. (Tăng) / giảm khác về tài sản hoạt động',
#   '-7,267,079,000,000',
#   '-30,045,854,000,000',
#   '33,421,448,000,000',
#   ''],
#  ['Thay đổi công nợ hoạt động', '', '', '', ''],
#  ['13. Tăng / (giảm) nợ chính phủ và Ngân hàng Nhà nước Việt Nam',
#   '84,485,182,000,000',
#   '57,846,700,000,000',
#   '-5,147,048,000,000',
#   ''],
#  ['14. Tăng / (giảm) tiền gửi và vay các tổ chức tín dụng',
#   '70,000,856,000,000',
#   '122,753,073,000,000',
#   '22,823,618,000,000',
#   ''],
#  ['15. Tăng / (giảm) tiền gửi của khách hàng',
#   '61,826,988,000,000',
#   '108,144,559,000,000',
#   '38,019,445,000,000',
#   ''],
#  ['16. Tăng / (giảm) vốn tài trợ, ủy thác đầu tư, cho vay và Ngân hàng chịu rủi ro',
#   '-3,322,000,000',
#   '-4,409,000,000',
#   '-1,112,000,000',
#   ''],
#  ['17. Tăng / (giảm) phát hành giấy tờ có giá',
#   '-2,688,755,000,000',
#   '7,950,797,000,000',
#   '1,999,996,000,000',
#   ''],
#  ['18. Tăng / (giảm) các công cụ tài chính phái sinh và các khoản nợ tài chính khác',
#   '120,079,000,000',
#   '',
#   '-31,994,056,000,000',
#   ''],
#  ['19. Tăng / (giảm) khác về công nợ hoạt động',
#   '-92,590,000,000',
#   '72,841,154,000,000',
#   '',
#   ''],
#  ['20. Chi từ các quỹ',
#   '-2,059,469,000,000',
#   '-2,538,653,000,000',
#   '-1,092,983,000,000',
#   ''],
#  ['Lưu chuyển tiền thuần từ hoạt động kinh doanh',
#   '60,896,734,000,000',
#   '183,375,344,000,000',
#   '47,586,319,000,000',
#   ''],
#  ['Lưu chuyển tiền từ hoạt động đầu tư', '', '', '', ''],
#  ['1. Mua sắm tài sản cố định (*)',
#   '-71,026,000,000',
#   '-711,567,000,000',
#   '-73,876,000,000',
#   ''],
#  ['2. Tiền thu từ thanh lý, nhượng bán tài sản cố định',
#   '10,291,000,000',
#   '15,753,000,000',
#   '2,071,000,000',
#   ''],
#  ['3. Tiền chi từ thanh lý, nhượng bán tài sản cố định (*)',
#   '-3,274,000,000',
#   '-4,808,000,000',
#   '-27,000,000',
#   ''],
#  ['4. Mua sắm bất động sản đầu tư (*)', '', '', '', ''],
#  ['5. Tiền thu từ bán, thanh lý bất động sản đầu tư', '', '', '', ''],
#  ['6. Tiền chi ra do bán, thanh lý bất động sản đầu tư (*)', '', '', '', ''],
#  ['7. Tiền chi đầu tư, góp vốn vào các đơn vị khác (*)', '', '', '', ''],
#  ['8. Tiền thu hồi đầu tư, góp vốn vào các đơn vị khác',
#   '201,898,000,000',
#   '201,899,000,000',
#   '10,685,000,000',
#   ''],
#  ['9. Tiền thu cổ tức và lợi nhuận được chia từ các khoản đầu tư, góp vốn dài hạn',
#   '104,378,000,000',
#   '107,054,000,000',
#   '11,779,000,000',
#   ''],
#  ['II. Lưu chuyển tiền thuần từ hoạt động đầu tư',
#   '242,267,000,000',
#   '-391,669,000,000',
#   '-49,368,000,000',
#   ''],
#  ['10. Tiền thu cổ tức đã có quyết định trả cổ tức năm trước', '', '', '', ''],
#  ['11. Hoạt động đầu tư khác', '', '', '', ''],
#  ['Lưu chuyển tiền tệ từ hoạt động tài chính', '', '', '', ''],
#  ['1. Tăng vốn cổ phần từ góp vốn và/hoặc phát hành cổ phiếu', '', '', '', ''],
#  ['2. Tiền thu từ phát hành giấy tờ có giá dài hạn đủ điều kiện tính vào vốn tự có và các khoản vốn vay dài hạn khác',
#   '',
#   '',
#   '',
#   ''],
#  ['3. Tiền chi thanh toán giấy tờ có giá dài hạn đủ điều kiện tính vào vốn tự có và các khoản vốn vay dài hạn khác (*)',
#   '',
#   '',
#   '',
#   ''],
#  ['4. Cổ tức trả cho cổ đông và lợi nhuận đã chia (*)',
#   '-3,329,224,000,000',
#   '-3,348,022,000,000',
#   '',
#   ''],
#  ['5. Tiền chi ra mua cổ phiếu quỹ (*)', '', '', '', ''],
#  ['6. Tiền thu được do bán cổ phiếu quỹ', '', '', '', ''],
#  ['7. Chi từ các quỹ', '', '', '', ''],
#  ['8. Các khoản khác', '', '', '', ''],
#  ['III. Lưu chuyển tiền thuần từ hoạt động tài chính',
#   '-3,329,224,000,000',
#   '-3,348,022,000,000',
#   '',
#   ''],
#  ['IV. Lưu chuyển tiền thuần trong kì',
#   '57,809,777,000,000',
#   '179,635,653,000,000',
#   '47,536,951,000,000',
#   ''],
#  ['V. Tiền và các khoản tương đương tiền tại thời điểm đầu kì',
#   '232,553,995,000,000',
#   '232,553,995,000,000',
#   '412,235,294,000,000',
#   ''],
#  ['VI. Điều chỉnh ảnh hưởng của thay đổi tỷ giá', '', '', '', ''],
#  ['Giảm tiền và các khoản tương đương tiền do thanh lý công ty con',
#   '',
#   '',
#   '',
#   ''],
#  ['VII. Tiền và các khoản tương đương tiền tại thời điểm cuối kì',
#   '290,363,772,000,000',
#   '412,189,648,000,000',
#   '459,772,245,000,000',
#   '']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(formatted_data)
df.head(20)
# Out:
#                                                     0                     1  \
# 0   VCB_CrawData_Lưu_Chuyển _Tiền_Tệ_Trực_Tiếp_The...                  None
# 1                                                                Quý 3-2022
# 2          I. Lưu chuyển tiền từ hoạt động kinh doanh
# 3   1. Thu nhập lãi và các khoản thu nhập tương tự...    61,693,757,000,000
# 4       2. Chi phí lãi và các chi phí tương tự đã trả   -20,664,896,000,000
# 5          3. Thu nhập từ hoạt động dịch vụ nhận được     3,668,176,000,000
# 6   4. Chênh lệch số tiền thực thu / (thực chi) từ...     4,800,414,000,000
# 7   5. Thu nhập thuần từ chứng khoán kinh doanh và...
# 8                        5. Thu nhập / (chi phí) khác      -211,915,000,000
# 9   6. Tiền thu từ các khoản nợ đã được xử lý xóa,...     1,959,262,000,000
# 10  6. Tiền chi trả cho nhân viên và hoạt động quả...   -12,755,544,000,000
# 11            7. Tiền thuế thu nhập thực nộp trong kỳ    -3,933,379,000,000
# 12  Lưu chuyển tiền thuần từ hoạt động kinh doanh ...    34,555,875,000,000
# 13                         Thay đổi tài sản hoạt động
# 14  8. (Tăng) / giảm tiền, vàng gửi và cho vay các...   -11,695,778,000,000
# 15         9. (Tăng) / giảm về kinh doanh chứng khoán     3,102,847,000,000
# 16  10. (Tăng) / giảm các công cụ tài chính phái s...       303,202,000,000
# 17     11. (Tăng) / giảm các khoản cho vay khách hàng  -169,394,046,000,000
# 18  11. Giảm nguồn dự phòng để bù đắp tổn thất các...      -297,256,000,000
# 19        12. (Tăng) / giảm khác về tài sản hoạt động    -7,267,079,000,000
#
#                        2                    3           4
# 0                   None                 None        None
# 1             Quý 4-2022           Quý 1-2023  Quý 2-2023
# 2
# 3     86,066,830,000,000   26,870,255,000,000
# 4    -31,709,129,000,000  -10,245,350,000,000
# 5      5,159,968,000,000    1,036,571,000,000
# 6      5,975,176,000,000    1,661,244,000,000
# 7
# 8       -351,732,000,000      684,356,000,000
# 9      2,394,744,000,000      396,375,000,000
# 10   -19,844,137,000,000   -5,387,579,000,000
# 11    -3,976,079,000,000   -5,577,486,000,000
# 12    43,715,641,000,000    9,438,386,000,000
# 13
# 14   -15,019,465,000,000   17,257,309,000,000
# 15     5,431,755,000,000   -8,025,946,000,000
# 16       146,687,000,000      -68,110,000,000
# 17  -184,316,295,000,000  -29,014,714,000,000
# 18    -3,530,346,000,000      -29,914,000,000
# 19   -30,045,854,000,000   33,421,448,000,000
