# %%
# !pip install beautifulsoup4

# %%
import requests
import json
from bs4 import BeautifulSoup
x = requests.get('https://s.cafef.vn/bao-cao-tai-chinh/VCB/BSheet/2023/0/0/0/0/bao-cao-tai-chinh-ngan-hang-thuong-mai-co-phan-ngoai-thuong-viet-nam.chn')

htmldiv = BeautifulSoup(x.content)

tableData = htmldiv.find("table", {"id": "tableContent"})

cellHeaders = htmldiv.find("table", {"id": "tblGridData"}).find("tr").find_all("td")[1:5]
jsonTitle = []
jsonTitle.append("VCB_BaoCaoTaiChinh_Theo năm")
jsonHeader = []
for cellHeader in cellHeaders:
  jsonHeader.append(cellHeader.text.strip())

linesTable = tableData.find_all("tr")

jsonData = []

for lineTable in linesTable:
  cellTables = lineTable.find_all("td", limit=5)
  jsonData_line = []
  for cellTable in cellTables:
    jsonData_line.append(cellTable.text.strip())
  jsonData.append(jsonData_line)

jsonData.insert(0, [ *jsonTitle])
jsonData.insert(1, ["", *jsonHeader])

f = open("data.json", "w")
f.write(json.dumps(jsonData))
f.close()

f = open("data.json", "r")
jsonDataReaded = f.read()

jsonDataFormated = json.loads(jsonDataReaded)
formatted_data = [row for row in jsonDataFormated if any(row)]
formatted_data

# import pandas as pd
# df = pd.DataFrame(formatted_data)
# df
# Out:
# [['VCB_BaoCaoTaiChinh_Theo năm'],
#  ['', '2019', '2020', '2021', '2022'],
#  ['I. TÀI SẢN', '', '', '', ''],
#  ['1. Tiền mặt và các khoản tương đương tại quỹ',
#   '13,778,358,000,000',
#   '15,095,394,000,000',
#   '18,011,766,000,000',
#   '18,348,534,000,000'],
#  ['2. Tiền gửi tại NHNN',
#   '34,684,091,000,000',
#   '33,139,373,000,000',
#   '22,506,711,000,000',
#   '92,557,809,000,000'],
#  ['Tiền gửi thanh toán tại các TCTD khác', '', '', '', ''],
#  ['3. Tiền, vàng gửi tại các TCTD khác và cho vay các TCTD khác',
#   '249,470,372,000,000',
#   '267,969,645,000,000',
#   '225,764,546,000,000',
#   '313,637,444,000,000'],
#  ['Tiền, vàng gửi tại TCTD khác',
#   '190,100,329,000,000',
#   '204,713,783,000,000',
#   '181,036,981,000,000',
#   '283,727,719,000,000'],
#  ['Cho vay các TCTD khác',
#   '62,370,043,000,000',
#   '64,255,862,000,000',
#   '48,727,565,000,000',
#   '40,749,725,000,000'],
#  ['Dự phòng rủi ro cho vay các TCTD khác',
#   '-3,000,000,000,000',
#   '-1,000,000,000,000',
#   '-4,000,000,000,000',
#   '-10,840,000,000,000'],
#  ['4. Cho vay khách hàng',
#   '724,290,102,000,000',
#   '820,545,467,000,000',
#   '934,774,287,000,000',
#   '1,120,286,832,000,000'],
#  ['Cho vay khách hàng',
#   '734,706,891,000,000',
#   '839,788,261,000,000',
#   '960,749,955,000,000',
#   '1,145,066,250,000,000'],
#  ['- Cơ cấu nợ theo nhóm', '', '', '', ''],
#  ['+ Nợ đủ tiêu chuẩn', '', '', '', ''],
#  ['+ Nợ cần chú ý', '', '', '', ''],
#  ['+ Nợ dưới tiêu chuẩn', '', '', '', ''],
#  ['+ Nợ nghi ngờ', '', '', '', ''],
#  ['+ Nợ có khả năng mất vốn', '', '', '', ''],
#  ['- Cơ cấu nợ theo kỳ hạn', '', '', '', ''],
#  ['+ Ngắn hạn', '', '', '', ''],
#  ['+ Trung hạn', '', '', '', ''],
#  ['+ Dài hạn', '', '', '', ''],
#  ['Dự phòng rủi ro cho vay khách hàng',
#   '-10,416,789,000,000',
#   '-19,242,794,000,000',
#   '-25,975,668,000,000',
#   '-24,779,418,000,000'],
#  ['5. Chứng khoán kinh doanh',
#   '1,801,126,000,000',
#   '1,954,061,000,000',
#   '2,766,098,000,000',
#   '1,499,687,000,000'],
#  ['5.1. Chứng khoán kinh doanh',
#   '1,889,628,000,000',
#   '1,991,861,000,000',
#   '2,822,531,000,000',
#   '1,543,575,000,000'],
#  ['5.4. Dự phòng giảm giá chứng khoán',
#   '-88,502,000,000',
#   '-37,800,000,000',
#   '-56,433,000,000',
#   '-43,888,000,000'],
#  ['6. Chứng khoán đầu tư',
#   '167,529,689,000,000',
#   '156,931,097,000,000',
#   '170,604,700,000,000',
#   '196,171,213,000,000'],
#  ['6.1. Chứng khoán đầu tư sẵn sàng để bán',
#   '35,699,090,000,000',
#   '42,148,831,000,000',
#   '71,122,502,000,000',
#   '100,739,670,000,000'],
#  ['6.2. Chứng khoán đầu tư giữ đến ngày đáo hạn',
#   '132,271,302,000,000',
#   '115,382,544,000,000',
#   '99,657,595,000,000',
#   '95,513,376,000,000'],
#  ['6.3 Dự phòng giảm giá chứng khoán',
#   '-440,703,000,000',
#   '-600,278,000,000',
#   '-175,397,000,000',
#   '-81,833,000,000'],
#  ['7. Các công cụ tài chính phái sinh và các tài sản tài chính khác',
#   '98,312,000,000',
#   '',
#   '303,202,000,000',
#   '156,515,000,000'],
#  ['8. Góp vốn, đầu tư dài hạn',
#   '2,464,493,000,000',
#   '2,239,006,000,000',
#   '2,346,176,000,000',
#   '2,193,535,000,000'],
#  ['8.1. Đầu tư vào công ty liên kết',
#   '10,863,000,000',
#   '11,248,000,000',
#   '10,820,000,000',
#   '11,314,000,000'],
#  ['8.2. Đầu tư dài hạn khác',
#   '1,587,823,000,000',
#   '1,587,823,000,000',
#   '1,661,461,000,000',
#   '1,529,145,000,000'],
#  ['8.3. Dự phòng giảm giá đầu tư dài hạn',
#   '-75,000,000,000',
#   '-75,000,000,000',
#   '-75,000,000,000',
#   '-117,999,000,000'],
#  ['8.4. Góp vốn liên doanh',
#   '940,807,000,000',
#   '714,935,000,000',
#   '748,895,000,000',
#   '771,075,000,000'],
#  ['9. Tài sản cố định',
#   '6,710,443,000,000',
#   '8,539,362,000,000',
#   '8,626,043,000,000',
#   '7,985,400,000,000'],
#  ['9.1. Tài sản cố định hữu hình',
#   '4,449,649,000,000',
#   '5,411,139,000,000',
#   '5,552,624,000,000',
#   '5,170,083,000,000'],
#  ['- Nguyên giá',
#   '11,161,239,000,000',
#   '12,866,189,000,000',
#   '13,725,160,000,000',
#   '13,950,174,000,000'],
#  ['- Giá trị hao mòn luỹ kế',
#   '-6,711,590,000,000',
#   '-7,455,050,000,000',
#   '-8,172,536,000,000',
#   '-8,780,091,000,000'],
#  ['9.2. Tài sản cố định thuê tài chính', '', '', '', ''],
#  ['- Nguyên giá', '', '', '', ''],
#  ['- Giá trị hao mòn luỹ kế', '', '', '', ''],
#  ['9.3. Tài sản cố định vô hình',
#   '2,260,794,000,000',
#   '3,128,223,000,000',
#   '3,073,419,000,000',
#   '2,815,317,000,000'],
#  ['- Nguyên giá',
#   '3,050,669,000,000',
#   '4,211,880,000,000',
#   '4,622,229,000,000',
#   '4,789,089,000,000'],
#  ['- Giá trị hao mòn luỹ kế',
#   '-789,875,000,000',
#   '-1,083,657,000,000',
#   '-1,548,810,000,000',
#   '-1,973,772,000,000'],
#  ['9.4. XDCB dở dang và mua sắm TSCĐ', '', '', '', ''],
#  ['10. Bất động sản đầu tư', '', '', '', ''],
#  ['- Nguyên giá', '', '', '', ''],
#  ['- Giá trị hao mòn luỹ kế', '', '', '', ''],
#  ['- Các khoản phải thu',
#   '8,829,375,000,000',
#   '6,668,595,000,000',
#   '15,796,141,000,000',
#   '24,483,406,000,000'],
#  ['- Các khoản lãi, phí phải thu',
#   '8,150,375,000,000',
#   '7,206,125,000,000',
#   '7,149,313,000,000',
#   '9,209,121,000,000'],
#  ['- Tài sản thuế TNDN hoãn lại',
#   '405,543,000,000',
#   '909,263,000,000',
#   '7,137,000,000',
#   '958,065,000,000'],
#  ['- Tài sản có khác',
#   '4,510,592,000,000',
#   '5,036,638,000,000',
#   '6,020,487,000,000',
#   '26,339,829,000,000'],
#  ['+ Trong đó lợi thế thương mại', '', '', '', ''],
#  ['- Các khoản dự phòng rủi ro cho các tài sản Có nội bảng khác',
#   '-3,794,000,000',
#   '-3,934,000,000',
#   '-4,020,000,000',
#   '-12,220,000,000'],
#  ['11. Tài sản Có khác',
#   '21,891,872,000,000',
#   '19,816,687,000,000',
#   '28,969,058,000,000',
#   '60,978,201,000,000'],
#  ['12. Hoạt động mua nợ', '', '', '', ''],
#  ['- Mua nợ', '', '', '', ''],
#  ['- Dự phòng rủi ro hoạt động mua nợ', '', '', '', ''],
#  ['Tổng tài sản',
#   '1,222,718,858,000,000',
#   '1,326,230,092,000,000',
#   '1,414,672,587,000,000',
#   '1,813,815,170,000,000'],
#  ['II. NGUỒN VỐN', '', '', '', ''],
#  ['1. Các khoản nợ Chính phủ và NHNN',
#   '92,365,806,000,000',
#   '41,176,995,000,000',
#   '9,468,116,000,000',
#   '67,314,816,000,000'],
#  ['1.1. Tiền gửi của KBNN', '', '', '', '67,314,816,000,000'],
#  ['1.2. Vay NHNN', '', '', '', ''],
#  ['2. Tiền gửi và vay các TCTD khác',
#   '73,617,085,000,000',
#   '103,583,833,000,000',
#   '109,575,777,000,000',
#   '232,510,850,000,000'],
#  ['2.1. Tiền gửi của các TCTD khác',
#   '71,046,512,000,000',
#   '100,916,433,000,000',
#   '104,043,817,000,000',
#   '222,040,585,000,000'],
#  ['2.2. Vay các TCTD khác',
#   '2,570,573,000,000',
#   '2,667,400,000,000',
#   '5,173,960,000,000',
#   '10,470,265,000,000'],
#  ['3. Tiền gửi của khách hàng',
#   '928,450,869,000,000',
#   '1,032,113,567,000,000',
#   '1,135,323,913,000,000',
#   '1,243,468,471,000,000'],
#  ['4. Các công cụ tài chính phái sinh và nợ tài chính khác',
#   '20,431,000,000',
#   '52,031,000,000',
#   '',
#   ''],
#  ['5. Vốn tài trợ, ủy thác đầu tư, cho vay TCTD chịu rủi ro',
#   '',
#   '14,679,000,000',
#   '7,707,000,000',
#   '3,298,000,000'],
#  ['6. Phát hành giấy tờ có giá',
#   '21,383,932,000,000',
#   '21,240,197,000,000',
#   '17,387,747,000,000',
#   '25,337,894,000,000'],
#  ['Thuế thu nhập doanh nghiệp', '', '', '', ''],
#  ['- Các khoản lãi, phí phải trả',
#   '10,382,357,000,000',
#   '9,797,834,000,000',
#   '9,326,334,000,000',
#   '12,485,332,000,000'],
#  ['- Các khoản phải trả và công nợ khác',
#   '15,593,373,000,000',
#   '24,155,977,000,000',
#   '24,283,600,000,000',
#   '97,048,424,000,000'],
#  ['- Dự phòng rủi ro khác', '', '', '', ''],
#  ['- Thuế TNDN phải trả', '', '', '', ''],
#  ['- Thuế TNDN hoãn lại phải trả', '22,023,000,000', '', '', ''],
#  ['7. Các khoản nợ khác',
#   '25,997,753,000,000',
#   '33,953,811,000,000',
#   '33,609,934,000,000',
#   '109,533,756,000,000'],
#  ['Tổng nợ phải trả',
#   '1,141,835,876,000,000',
#   '1,232,135,113,000,000',
#   '1,305,555,194,000,000',
#   '1,678,169,085,000,000'],
#  ['8. Vốn và các quỹ',
#   '80,882,982,000,000',
#   '94,094,979,000,000',
#   '109,117,393,000,000',
#   '135,646,085,000,000'],
#  ['8.1. Vốn của TCTD',
#   '42,428,820,000,000',
#   '42,428,821,000,000',
#   '42,428,821,000,000',
#   '53,130,392,000,000'],
#  ['- Vốn điều lệ',
#   '37,088,774,000,000',
#   '37,088,774,000,000',
#   '37,088,774,000,000',
#   '47,325,166,000,000'],
#  ['- Vốn đầu tư XDCB', '', '', '', ''],
#  ['- Thặng dư vốn cổ phần',
#   '4,995,389,000,000',
#   '4,995,389,000,000',
#   '4,995,389,000,000',
#   '4,995,389,000,000'],
#  ['- Cổ phiếu quỹ (*)', '', '', '', ''],
#  ['- Cổ phiếu ưu đãi', '', '', '', ''],
#  ['- Vốn khác',
#   '344,657,000,000',
#   '344,658,000,000',
#   '344,658,000,000',
#   '809,837,000,000'],
#  ['8.2. Quỹ của TCTD',
#   '12,186,141,000,000',
#   '14,925,803,000,000',
#   '18,173,068,000,000',
#   '22,556,958,000,000'],
#  ['- Các quỹ dự trữ', '', '', '', ''],
#  ['8.3. Lợi nhuận chưa phân phối/Lỗ lũy kế',
#   '26,055,190,000,000',
#   '36,650,228,000,000',
#   '48,433,500,000,000',
#   '60,733,423,000,000'],
#  ['8.4. Lợi nhuận năm nay',
#   '16,361,000,000',
#   '5,103,000,000',
#   '-5,109,000,000',
#   '-863,071,000,000'],
#  ['8.5. Lợi nhuận năm trước', '113,011,000,000', '', '', ''],
#  ['8.7. Chênh lệch đánh giá lại tài sản', '113,011,000,000', '', '', ''],
#  ['8.6. Chênh lệch tỷ giá hối đoái',
#   '16,361,000,000',
#   '5,103,000,000',
#   '-5,109,000,000',
#   '-863,071,000,000'],
#  ['9. Lợi ích của cổ đông thiểu số',
#   '83,459,000,000',
#   '85,024,000,000',
#   '87,113,000,000',
#   '88,383,000,000'],
#  ['Tổng cộng nguồn vốn',
#   '1,222,718,858,000,000',
#   '1,326,230,092,000,000',
#   '1,414,672,587,000,000',
#   '1,813,815,170,000,000'],
#  ['Các khoản mục ghi nhớ', '', '', '', ''],
#  ['1. Thư tín dụng trả ngay', '', '', '', ''],
#  ['2. Thư tín dụng trả chậm', '', '', '', ''],
#  ['3. Bảo lãnh thanh toán', '', '', '', ''],
#  ['4. Bảo lãnh vay vốn', '', '', '', ''],
#  ['5. Bảo lãnh khác', '', '', '', ''],
#  ['6. Cam kết cho vay chưa giải ngân', '', '', '', ''],
#  ['7. Các cam kết khác', '', '', '', '']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(formatted_data)
df.head(20)
# Out:
#                                                     0                    1  \
# 0                         VCB_BaoCaoTaiChinh_Theo năm                 None
# 1                                                                     2019
# 2                                          I. TÀI SẢN
# 3        1. Tiền mặt và các khoản tương đương tại quỹ   13,778,358,000,000
# 4                                2. Tiền gửi tại NHNN   34,684,091,000,000
# 5               Tiền gửi thanh toán tại các TCTD khác
# 6   3. Tiền, vàng gửi tại các TCTD khác và cho vay...  249,470,372,000,000
# 7                        Tiền, vàng gửi tại TCTD khác  190,100,329,000,000
# 8                               Cho vay các TCTD khác   62,370,043,000,000
# 9               Dự phòng rủi ro cho vay các TCTD khác   -3,000,000,000,000
# 10                              4. Cho vay khách hàng  724,290,102,000,000
# 11                                 Cho vay khách hàng  734,706,891,000,000
# 12                              - Cơ cấu nợ theo nhóm
# 13                                 + Nợ đủ tiêu chuẩn
# 14                                     + Nợ cần chú ý
# 15                               + Nợ dưới tiêu chuẩn
# 16                                      + Nợ nghi ngờ
# 17                           + Nợ có khả năng mất vốn
# 18                            - Cơ cấu nợ theo kỳ hạn
# 19                                         + Ngắn hạn
#
#                       2                    3                      4
# 0                  None                 None                   None
# 1                  2020                 2021                   2022
# 2
# 3    15,095,394,000,000   18,011,766,000,000     18,348,534,000,000
# 4    33,139,373,000,000   22,506,711,000,000     92,557,809,000,000
# 5
# 6   267,969,645,000,000  225,764,546,000,000    313,637,444,000,000
# 7   204,713,783,000,000  181,036,981,000,000    283,727,719,000,000
# 8    64,255,862,000,000   48,727,565,000,000     40,749,725,000,000
# 9    -1,000,000,000,000   -4,000,000,000,000    -10,840,000,000,000
# 10  820,545,467,000,000  934,774,287,000,000  1,120,286,832,000,000
# 11  839,788,261,000,000  960,749,955,000,000  1,145,066,250,000,000
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
