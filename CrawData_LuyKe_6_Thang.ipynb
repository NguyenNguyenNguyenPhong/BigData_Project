# %%
# !pip install beautifulsoup4

# %%
import requests
import json
from bs4 import BeautifulSoup
x = requests.get('https://s.cafef.vn/bao-cao-tai-chinh/VCB/BSheet/2023/2/0/0/3/bao-cao-tai-chinh-ngan-hang-thuong-mai-co-phan-ngoai-thuong-viet-nam.chn')

htmldiv = BeautifulSoup(x.content)

tableData = htmldiv.find("table", {"id": "tableContent"})

cellHeaders = htmldiv.find("table", {"id": "tblGridData"}).find("tr").find_all("td")[1:5]
jsonTitle = []
jsonTitle.append("VCB_BaoCaoLuyKe_6_Thang")
jsonHeader = []
for cellHeader in cellHeaders:
  jsonHeader.append(cellHeader.text.strip())

linesTable = tableData.find_all("tr")

jsonData = []

for lineTable in linesTable:
  cellTables = lineTable.find_all("td", limit=5)
  jsonData_line = []
  for cellTable in cellTables:
    jsonData_line.append(cellTable.text.strip())
  jsonData.append(jsonData_line)

jsonData.insert(0, [ *jsonTitle])
jsonData.insert(1, ["", *jsonHeader])

f = open("data.json", "w")
f.write(json.dumps(jsonData))
f.close()

f = open("data.json", "r")
jsonDataReaded = f.read()

jsonDataFormated = json.loads(jsonDataReaded)
formatted_data = [row for row in jsonDataFormated if any(row)]
formatted_data

# import pandas as pd
# df = pd.DataFrame(formatted_data)
# df
# Out:
# [['VCB_BaoCaoLuyKe_6_Thang'],
#  ['',
#   'LK 6 tháng 2020(Đã soát xét)',
#   'LK 6 tháng 2021(Đã soát xét)',
#   'LK 6 tháng 2022(Đã soát xét)',
#   ''],
#  ['I. TÀI SẢN', '', '', '', ''],
#  ['1. Tiền mặt và các khoản tương đương tại quỹ',
#   '11,863,544,000,000',
#   '13,132,285,000,000',
#   '15,097,807,000,000',
#   ''],
#  ['2. Tiền gửi tại NHNN',
#   '71,566,703,000,000',
#   '23,485,760,000,000',
#   '28,813,961,000,000',
#   ''],
#  ['Tiền gửi thanh toán tại các TCTD khác', '', '', '', ''],
#  ['3. Tiền, vàng gửi tại các TCTD khác và cho vay các TCTD khác',
#   '150,761,888,000,000',
#   '185,877,601,000,000',
#   '255,536,982,000,000',
#   ''],
#  ['Tiền, vàng gửi tại TCTD khác',
#   '128,821,053,000,000',
#   '164,585,658,000,000',
#   '206,455,463,000,000',
#   ''],
#  ['Cho vay các TCTD khác',
#   '22,940,835,000,000',
#   '22,291,943,000,000',
#   '50,081,519,000,000',
#   ''],
#  ['Dự phòng rủi ro cho vay các TCTD khác',
#   '-1,000,000,000,000',
#   '-1,000,000,000,000',
#   '-1,000,000,000,000',
#   ''],
#  ['4. Cho vay khách hàng',
#   '754,374,040,000,000',
#   '897,798,104,000,000',
#   '1,066,990,245,000,000',
#   ''],
#  ['Cho vay khách hàng',
#   '770,744,422,000,000',
#   '912,948,437,000,000',
#   '1,100,852,163,000,000',
#   ''],
#  ['- Cơ cấu nợ theo nhóm', '', '', '', ''],
#  ['+ Nợ đủ tiêu chuẩn', '', '', '', ''],
#  ['+ Nợ cần chú ý', '', '', '', ''],
#  ['+ Nợ dưới tiêu chuẩn', '', '', '', ''],
#  ['+ Nợ nghi ngờ', '', '', '', ''],
#  ['+ Nợ có khả năng mất vốn', '', '', '', ''],
#  ['- Cơ cấu nợ theo kỳ hạn', '', '', '', ''],
#  ['+ Ngắn hạn', '', '', '', ''],
#  ['+ Trung hạn', '', '', '', ''],
#  ['+ Dài hạn', '', '', '', ''],
#  ['Dự phòng rủi ro cho vay khách hàng',
#   '-16,370,382,000,000',
#   '-24,150,333,000,000',
#   '-33,861,918,000,000',
#   ''],
#  ['5. Chứng khoán kinh doanh',
#   '3,556,653,000,000',
#   '3,182,256,000,000',
#   '3,150,052,000,000',
#   ''],
#  ['5.1. Chứng khoán kinh doanh',
#   '3,641,851,000,000',
#   '3,221,327,000,000',
#   '3,187,225,000,000',
#   ''],
#  ['5.4. Dự phòng giảm giá chứng khoán',
#   '-85,198,000,000',
#   '-39,071,000,000',
#   '-37,173,000,000',
#   ''],
#  ['6. Chứng khoán đầu tư',
#   '163,458,200,000,000',
#   '147,996,760,000,000',
#   '191,407,933,000,000',
#   ''],
#  ['6.1. Chứng khoán đầu tư sẵn sàng để bán',
#   '28,375,703,000,000',
#   '49,339,958,000,000',
#   '101,203,452,000,000',
#   ''],
#  ['6.2. Chứng khoán đầu tư giữ đến ngày đáo hạn',
#   '135,577,712,000,000',
#   '99,230,545,000,000',
#   '90,293,045,000,000',
#   ''],
#  ['6.3 Dự phòng giảm giá chứng khoán',
#   '-495,215,000,000',
#   '-573,743,000,000',
#   '-88,564,000,000',
#   ''],
#  ['7. Các công cụ tài chính phái sinh và các tài sản tài chính khác',
#   '',
#   '',
#   '',
#   ''],
#  ['8. Góp vốn, đầu tư dài hạn',
#   '2,329,091,000,000',
#   '2,281,134,000,000',
#   '2,380,804,000,000',
#   ''],
#  ['8.1. Đầu tư vào công ty liên kết',
#   '13,258,000,000',
#   '13,423,000,000',
#   '8,121,000,000',
#   ''],
#  ['8.2. Đầu tư dài hạn khác',
#   '1,678,126,000,000',
#   '1,587,823,000,000',
#   '1,659,597,000,000',
#   ''],
#  ['8.3. Dự phòng giảm giá đầu tư dài hạn',
#   '-75,000,000,000',
#   '-75,000,000,000',
#   '-75,000,000,000',
#   ''],
#  ['8.4. Góp vốn liên doanh',
#   '712,707,000,000',
#   '754,888,000,000',
#   '788,086,000,000',
#   ''],
#  ['9. Tài sản cố định',
#   '6,723,876,000,000',
#   '8,317,891,000,000',
#   '8,103,519,000,000',
#   ''],
#  ['9.1. Tài sản cố định hữu hình',
#   '4,409,846,000,000',
#   '5,363,219,000,000',
#   '5,249,947,000,000',
#   ''],
#  ['- Nguyên giá',
#   '11,485,262,000,000',
#   '13,221,132,000,000',
#   '13,797,299,000,000',
#   ''],
#  ['- Giá trị hao mòn luỹ kế',
#   '-7,075,416,000,000',
#   '-7,857,913,000,000',
#   '-8,547,352,000,000',
#   ''],
#  ['9.2. Tài sản cố định thuê tài chính', '', '', '', ''],
#  ['- Nguyên giá', '', '', '', ''],
#  ['- Giá trị hao mòn luỹ kế', '', '', '', ''],
#  ['9.3. Tài sản cố định vô hình',
#   '2,314,030,000,000',
#   '2,954,672,000,000',
#   '2,853,572,000,000',
#   ''],
#  ['- Nguyên giá',
#   '3,161,694,000,000',
#   '4,213,943,000,000',
#   '4,617,993,000,000',
#   ''],
#  ['- Giá trị hao mòn luỹ kế',
#   '-847,664,000,000',
#   '-1,259,271,000,000',
#   '-1,764,421,000,000',
#   ''],
#  ['9.4. XDCB dở dang và mua sắm TSCĐ', '', '', '', ''],
#  ['10. Bất động sản đầu tư', '', '', '', ''],
#  ['- Nguyên giá', '', '', '', ''],
#  ['- Giá trị hao mòn luỹ kế', '', '', '', ''],
#  ['- Các khoản phải thu',
#   '10,727,414,000,000',
#   '9,714,405,000,000',
#   '18,005,150,000,000',
#   ''],
#  ['- Các khoản lãi, phí phải thu',
#   '6,871,123,000,000',
#   '6,187,719,000,000',
#   '7,156,290,000,000',
#   ''],
#  ['- Tài sản thuế TNDN hoãn lại',
#   '6,821,000,000',
#   '909,210,000,000',
#   '7,927,000,000',
#   ''],
#  ['- Tài sản có khác',
#   '3,636,257,000,000',
#   '5,300,001,000,000',
#   '5,035,736,000,000',
#   ''],
#  ['+ Trong đó lợi thế thương mại', '', '', '', ''],
#  ['- Các khoản dự phòng rủi ro cho các tài sản Có nội bảng khác',
#   '-3,948,000,000',
#   '-4,020,000,000',
#   '-5,442,000,000',
#   ''],
#  ['11. Tài sản Có khác',
#   '21,237,667,000,000',
#   '22,107,315,000,000',
#   '30,199,661,000,000',
#   ''],
#  ['12. Hoạt động mua nợ', '', '', '', ''],
#  ['- Mua nợ', '', '', '', ''],
#  ['- Dự phòng rủi ro hoạt động mua nợ', '', '', '', ''],
#  ['Tổng tài sản',
#   '1,185,871,662,000,000',
#   '1,304,179,106,000,000',
#   '1,601,680,964,000,000',
#   ''],
#  ['II. NGUỒN VỐN', '', '', '', ''],
#  ['1. Các khoản nợ Chính phủ và NHNN',
#   '10,326,096,000,000',
#   '9,077,476,000,000',
#   '61,020,549,000,000',
#   ''],
#  ['1.1. Tiền gửi của KBNN', '', '', '61,020,549,000,000', ''],
#  ['1.2. Vay NHNN', '', '', '', ''],
#  ['2. Tiền gửi và vay các TCTD khác',
#   '48,404,237,000,000',
#   '84,188,617,000,000',
#   '171,676,891,000,000',
#   ''],
#  ['2.1. Tiền gửi của các TCTD khác',
#   '46,551,237,000,000',
#   '80,671,606,000,000',
#   '159,084,451,000,000',
#   ''],
#  ['2.2. Vay các TCTD khác',
#   '1,853,000,000,000',
#   '3,517,011,000,000',
#   '12,592,440,000,000',
#   ''],
#  ['3. Tiền gửi của khách hàng',
#   '981,240,858,000,000',
#   '1,051,273,660,000,000',
#   '1,195,391,576,000,000',
#   ''],
#  ['4. Các công cụ tài chính phái sinh và nợ tài chính khác',
#   '59,126,000,000',
#   '30,621,000,000',
#   '19,457,000,000',
#   ''],
#  ['5. Vốn tài trợ, ủy thác đầu tư, cho vay TCTD chịu rủi ro',
#   '17,930,000,000',
#   '9,884,000,000',
#   '5,485,000,000',
#   ''],
#  ['6. Phát hành giấy tờ có giá',
#   '21,294,140,000,000',
#   '31,398,107,000,000',
#   '14,367,033,000,000',
#   ''],
#  ['Thuế thu nhập doanh nghiệp', '', '', '', ''],
#  ['- Các khoản lãi, phí phải trả',
#   '10,928,812,000,000',
#   '9,366,261,000,000',
#   '10,960,439,000,000',
#   ''],
#  ['- Các khoản phải trả và công nợ khác',
#   '24,021,760,000,000',
#   '23,894,962,000,000',
#   '25,249,837,000,000',
#   ''],
#  ['- Dự phòng rủi ro khác', '', '', '', ''],
#  ['- Thuế TNDN phải trả', '', '', '', ''],
#  ['- Thuế TNDN hoãn lại phải trả', '243,000,000', '', '', ''],
#  ['7. Các khoản nợ khác',
#   '34,950,815,000,000',
#   '33,261,223,000,000',
#   '36,210,276,000,000',
#   ''],
#  ['Tổng nợ phải trả',
#   '1,096,293,202,000,000',
#   '1,199,239,588,000,000',
#   '1,478,691,267,000,000',
#   ''],
#  ['8. Vốn và các quỹ',
#   '89,578,460,000,000',
#   '104,939,518,000,000',
#   '122,989,697,000,000',
#   ''],
#  ['8.1. Vốn của TCTD',
#   '42,428,820,000,000',
#   '42,518,184,000,000',
#   '52,665,213,000,000',
#   ''],
#  ['- Vốn điều lệ',
#   '37,088,774,000,000',
#   '37,088,774,000,000',
#   '47,325,166,000,000',
#   ''],
#  ['- Vốn đầu tư XDCB', '', '', '', ''],
#  ['- Thặng dư vốn cổ phần',
#   '4,995,389,000,000',
#   '4,995,389,000,000',
#   '4,995,389,000,000',
#   ''],
#  ['- Cổ phiếu quỹ (*)', '', '', '', ''],
#  ['- Cổ phiếu ưu đãi', '', '', '', ''],
#  ['- Vốn khác', '344,657,000,000', '434,021,000,000', '344,658,000,000', ''],
#  ['8.2. Quỹ của TCTD',
#   '12,183,712,000,000',
#   '14,916,935,000,000',
#   '18,171,942,000,000',
#   ''],
#  ['- Các quỹ dự trữ', '', '', '', ''],
#  ['8.3. Lợi nhuận chưa phân phối/Lỗ lũy kế',
#   '34,845,164,000,000',
#   '47,408,227,000,000',
#   '52,056,550,000,000',
#   ''],
#  ['8.4. Lợi nhuận năm nay',
#   '27,265,000,000',
#   '1,708,000,000',
#   '-1,782,000,000',
#   ''],
#  ['8.5. Lợi nhuận năm trước', '', '', '', ''],
#  ['8.7. Chênh lệch đánh giá lại tài sản', '', '', '', ''],
#  ['8.6. Chênh lệch tỷ giá hối đoái',
#   '27,265,000,000',
#   '1,708,000,000',
#   '-1,782,000,000',
#   ''],
#  ['9. Lợi ích của cổ đông thiểu số',
#   '93,499,000,000',
#   '94,464,000,000',
#   '97,774,000,000',
#   ''],
#  ['Tổng cộng nguồn vốn',
#   '1,185,871,662,000,000',
#   '1,304,179,106,000,000',
#   '1,601,680,964,000,000',
#   ''],
#  ['Các khoản mục ghi nhớ', '', '', '', ''],
#  ['1. Thư tín dụng trả ngay', '', '', '', ''],
#  ['2. Thư tín dụng trả chậm', '', '', '', ''],
#  ['3. Bảo lãnh thanh toán', '', '', '', ''],
#  ['4. Bảo lãnh vay vốn', '', '', '', ''],
#  ['5. Bảo lãnh khác', '', '', '', ''],
#  ['6. Cam kết cho vay chưa giải ngân', '', '', '', ''],
#  ['7. Các cam kết khác', '', '', '', '']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(formatted_data)
df.head(20)
# Out:
#                                                     0  \
# 0                             VCB_BaoCaoLuyKe_6_Thang
# 1
# 2                                          I. TÀI SẢN
# 3        1. Tiền mặt và các khoản tương đương tại quỹ
# 4                                2. Tiền gửi tại NHNN
# 5               Tiền gửi thanh toán tại các TCTD khác
# 6   3. Tiền, vàng gửi tại các TCTD khác và cho vay...
# 7                        Tiền, vàng gửi tại TCTD khác
# 8                               Cho vay các TCTD khác
# 9               Dự phòng rủi ro cho vay các TCTD khác
# 10                              4. Cho vay khách hàng
# 11                                 Cho vay khách hàng
# 12                              - Cơ cấu nợ theo nhóm
# 13                                 + Nợ đủ tiêu chuẩn
# 14                                     + Nợ cần chú ý
# 15                               + Nợ dưới tiêu chuẩn
# 16                                      + Nợ nghi ngờ
# 17                           + Nợ có khả năng mất vốn
# 18                            - Cơ cấu nợ theo kỳ hạn
# 19                                         + Ngắn hạn
#
#                                1                             2  \
# 0                           None                          None
# 1   LK 6 tháng 2020(Đã soát xét)  LK 6 tháng 2021(Đã soát xét)
# 2
# 3             11,863,544,000,000            13,132,285,000,000
# 4             71,566,703,000,000            23,485,760,000,000
# 5
# 6            150,761,888,000,000           185,877,601,000,000
# 7            128,821,053,000,000           164,585,658,000,000
# 8             22,940,835,000,000            22,291,943,000,000
# 9             -1,000,000,000,000            -1,000,000,000,000
# 10           754,374,040,000,000           897,798,104,000,000
# 11           770,744,422,000,000           912,948,437,000,000
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
#
#                                3     4
# 0                           None  None
# 1   LK 6 tháng 2022(Đã soát xét)
# 2
# 3             15,097,807,000,000
# 4             28,813,961,000,000
# 5
# 6            255,536,982,000,000
# 7            206,455,463,000,000
# 8             50,081,519,000,000
# 9             -1,000,000,000,000
# 10         1,066,990,245,000,000
# 11         1,100,852,163,000,000
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
