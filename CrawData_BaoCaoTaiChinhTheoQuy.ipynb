# %%
# !pip install beautifulsoup4

# %%
import requests
import json
from bs4 import BeautifulSoup
x = requests.get('https://s.cafef.vn/bao-cao-tai-chinh/VCB/BSheet/2023/4/0/0/1/bao-cao-tai-chinh-ngan-hang-thuong-mai-co-phan-ngoai-thuong-viet-nam.chn')

htmldiv = BeautifulSoup(x.content)

tableData = htmldiv.find("table", {"id": "tableContent"})

cellHeaders = htmldiv.find("table", {"id": "tblGridData"}).find("tr").find_all("td")[1:5]
jsonTitle = []
jsonTitle.append("VCB_BaoCaoTaiChinh_Theo_Quy")
jsonHeader = []
for cellHeader in cellHeaders:
  jsonHeader.append(cellHeader.text.strip())

linesTable = tableData.find_all("tr")

jsonData = []

for lineTable in linesTable:
  cellTables = lineTable.find_all("td", limit=5)
  jsonData_line = []
  for cellTable in cellTables:
    jsonData_line.append(cellTable.text.strip())
  jsonData.append(jsonData_line)

jsonData.insert(0, [ *jsonTitle])
jsonData.insert(1, ["", *jsonHeader])

f = open("data.json", "w")
f.write(json.dumps(jsonData))
f.close()

f = open("data.json", "r")
jsonDataReaded = f.read()

jsonDataFormated = json.loads(jsonDataReaded)
formatted_data = [row for row in jsonDataFormated if any(row)]
formatted_data

# import pandas as pd
# df = pd.DataFrame(formatted_data)
# df
# Out:
# [['VCB_BaoCaoTaiChinh_Theo_Quy'],
#  ['', 'Quý 2-2022', 'Quý 3-2022', 'Quý 4-2022', 'Quý 1-2023'],
#  ['I. TÀI SẢN', '', '', '', ''],
#  ['1. Tiền mặt và các khoản tương đương tại quỹ',
#   '15,097,807,000,000',
#   '16,293,080,000,000',
#   '18,348,519,000,000',
#   '15,537,950,000,000'],
#  ['2. Tiền gửi tại NHNN',
#   '28,813,961,000,000',
#   '16,293,080,000,000',
#   '92,557,809,000,000',
#   '139,256,635,000,000'],
#  ['Tiền gửi thanh toán tại các TCTD khác', '', '', '', ''],
#  ['3. Tiền, vàng gửi tại các TCTD khác và cho vay các TCTD khác',
#   '255,548,453,000,000',
#   '302,927,159,000,000',
#   '313,591,813,000,000',
#   '334,747,844,000,000'],
#  ['Tiền, vàng gửi tại TCTD khác',
#   '206,466,934,000,000',
#   '254,958,471,000,000',
#   '283,682,088,000,000',
#   '324,773,255,000,000'],
#  ['Cho vay các TCTD khác',
#   '50,081,519,000,000',
#   '48,968,688,000,000',
#   '40,749,725,000,000',
#   '15,695,589,000,000'],
#  ['Dự phòng rủi ro cho vay các TCTD khác',
#   '-1,000,000,000,000',
#   '-1,000,000,000,000',
#   '-10,840,000,000,000',
#   '-5,721,000,000,000'],
#  ['4. Cho vay khách hàng',
#   '1,066,990,245,000,000',
#   '1,093,971,420,000,000',
#   '1,120,286,831,000,000',
#   '1,142,187,065,000,000'],
#  ['Cho vay khách hàng',
#   '1,100,852,163,000,000',
#   '1,130,144,001,000,000',
#   '1,145,066,250,000,000',
#   '1,174,080,964,000,000'],
#  ['- Cơ cấu nợ theo nhóm', '', '', '', ''],
#  ['+ Nợ đủ tiêu chuẩn', '', '', '', ''],
#  ['+ Nợ cần chú ý', '', '', '', ''],
#  ['+ Nợ dưới tiêu chuẩn', '', '', '', ''],
#  ['+ Nợ nghi ngờ', '', '', '', ''],
#  ['+ Nợ có khả năng mất vốn', '', '', '', ''],
#  ['- Cơ cấu nợ theo kỳ hạn', '', '', '', ''],
#  ['+ Ngắn hạn', '', '', '', ''],
#  ['+ Trung hạn', '', '', '', ''],
#  ['+ Dài hạn', '', '', '', ''],
#  ['Dự phòng rủi ro cho vay khách hàng',
#   '-33,861,918,000,000',
#   '-36,172,581,000,000',
#   '-24,779,419,000,000',
#   '-31,893,899,000,000'],
#  ['5. Chứng khoán kinh doanh',
#   '3,150,052,000,000',
#   '1,347,762,000,000',
#   '1,499,687,000,000',
#   '1,595,430,000,000'],
#  ['5.1. Chứng khoán kinh doanh',
#   '3,187,225,000,000',
#   '1,407,066,000,000',
#   '1,543,575,000,000',
#   '1,618,113,000,000'],
#  ['5.4. Dự phòng giảm giá chứng khoán',
#   '-37,173,000,000',
#   '-59,304,000,000',
#   '-43,888,000,000',
#   '-22,683,000,000'],
#  ['6. Chứng khoán đầu tư',
#   '191,407,933,000,000',
#   '177,219,709,000,000',
#   '196,171,212,000,000',
#   '174,526,186,000,000'],
#  ['6.1. Chứng khoán đầu tư sẵn sàng để bán',
#   '101,203,452,000,000',
#   '87,411,490,000,000',
#   '100,739,669,000,000',
#   '77,663,390,000,000'],
#  ['6.2. Chứng khoán đầu tư giữ đến ngày đáo hạn',
#   '90,293,045,000,000',
#   '89,896,772,000,000',
#   '95,513,376,000,000',
#   '96,941,064,000,000'],
#  ['6.3 Dự phòng giảm giá chứng khoán',
#   '-88,564,000,000',
#   '-88,553,000,000',
#   '-81,833,000,000',
#   '-78,268,000,000'],
#  ['7. Các công cụ tài chính phái sinh và các tài sản tài chính khác',
#   '',
#   '',
#   '156,515,000,000',
#   '224,625,000,000'],
#  ['8. Góp vốn, đầu tư dài hạn',
#   '2,380,804,000,000',
#   '2,217,065,000,000',
#   '2,193,516,000,000',
#   '2,221,085,000,000'],
#  ['8.1. Đầu tư vào công ty liên kết',
#   '8,121,000,000',
#   '9,674,000,000',
#   '11,313,000,000',
#   '12,664,000,000'],
#  ['8.2. Đầu tư dài hạn khác',
#   '1,659,597,000,000',
#   '1,529,145,000,000',
#   '1,529,145,000,000',
#   '1,529,145,000,000'],
#  ['8.3. Dự phòng giảm giá đầu tư dài hạn',
#   '-75,000,000,000',
#   '-75,000,000,000',
#   '-117,999,000,000',
#   '-117,999,000,000'],
#  ['8.4. Góp vốn liên doanh',
#   '788,086,000,000',
#   '753,246,000,000',
#   '771,057,000,000',
#   '797,275,000,000'],
#  ['9. Tài sản cố định',
#   '8,103,519,000,000',
#   '7,820,512,000,000',
#   '7,985,401,000,000',
#   '7,732,058,000,000'],
#  ['9.1. Tài sản cố định hữu hình',
#   '5,249,947,000,000',
#   '5,060,100,000,000',
#   '5,170,083,000,000',
#   '5,015,683,000,000'],
#  ['- Nguyên giá',
#   '13,797,299,000,000',
#   '13,806,057,000,000',
#   '13,950,173,000,000',
#   '14,021,442,000,000'],
#  ['- Giá trị hao mòn luỹ kế',
#   '-8,547,352,000,000',
#   '-8,745,957,000,000',
#   '-8,780,090,000,000',
#   '-9,005,759,000,000'],
#  ['9.2. Tài sản cố định thuê tài chính', '', '', '', ''],
#  ['- Nguyên giá', '', '', '', ''],
#  ['- Giá trị hao mòn luỹ kế', '', '', '', ''],
#  ['9.3. Tài sản cố định vô hình',
#   '2,853,572,000,000',
#   '2,760,412,000,000',
#   '2,815,318,000,000',
#   '2,716,375,000,000'],
#  ['- Nguyên giá',
#   '4,617,993,000,000',
#   '4,624,053,000,000',
#   '4,789,089,000,000',
#   '4,791,697,000,000'],
#  ['- Giá trị hao mòn luỹ kế',
#   '-1,764,421,000,000',
#   '-1,863,641,000,000',
#   '-1,973,771,000,000',
#   '-2,075,322,000,000'],
#  ['9.4. XDCB dở dang và mua sắm TSCĐ', '', '', '', ''],
#  ['10. Bất động sản đầu tư', '', '', '', ''],
#  ['- Nguyên giá', '', '', '', ''],
#  ['- Giá trị hao mòn luỹ kế', '', '', '', ''],
#  ['- Các khoản phải thu',
#   '18,467,522,000,000',
#   '24,545,840,000,000',
#   '24,932,725,000,000',
#   '15,382,146,000,000'],
#  ['- Các khoản lãi, phí phải thu',
#   '7,156,290,000,000',
#   '8,044,556,000,000',
#   '9,209,121,000,000',
#   '10,053,102,000,000'],
#  ['- Tài sản thuế TNDN hoãn lại',
#   '7,927,000,000',
#   '5,782,000,000',
#   '927,450,000,000',
#   '953,984,000,000'],
#  ['- Tài sản có khác',
#   '5,272,656,000,000',
#   '3,898,300,000,000',
#   '26,331,539,000,000',
#   '2,025,613,000,000'],
#  ['+ Trong đó lợi thế thương mại', '', '', '', ''],
#  ['- Các khoản dự phòng rủi ro cho các tài sản Có nội bảng khác',
#   '-5,442,000,000',
#   '-5,397,000,000',
#   '-3,929,000,000',
#   '-12,433,000,000'],
#  ['11. Tài sản Có khác',
#   '30,898,953,000,000',
#   '36,489,081,000,000',
#   '61,396,906,000,000',
#   '28,402,412,000,000'],
#  ['12. Hoạt động mua nợ', '', '', '', ''],
#  ['- Mua nợ', '', '', '', ''],
#  ['- Dự phòng rủi ro hoạt động mua nợ', '', '', '', ''],
#  ['Tổng tài sản',
#   '1,602,391,727,000,000',
#   '1,649,664,327,000,000',
#   '1,814,188,209,000,000',
#   '1,846,431,290,000,000'],
#  ['II. NGUỒN VỐN', '', '', '', ''],
#  ['1. Các khoản nợ Chính phủ và NHNN',
#   '61,020,549,000,000',
#   '93,953,298,000,000',
#   '67,314,816,000,000',
#   '62,167,768,000,000'],
#  ['1.1. Tiền gửi của KBNN',
#   '',
#   '93,953,298,000,000',
#   '',
#   '62,167,768,000,000'],
#  ['1.2. Vay NHNN', '', '', '', ''],
#  ['2. Tiền gửi và vay các TCTD khác',
#   '171,676,891,000,000',
#   '179,758,633,000,000',
#   '232,510,850,000,000',
#   '255,334,468,000,000'],
#  ['2.1. Tiền gửi của các TCTD khác',
#   '159,084,451,000,000',
#   '173,006,463,000,000',
#   '222,040,585,000,000',
#   '237,183,063,000,000'],
#  ['2.2. Vay các TCTD khác',
#   '12,592,440,000,000',
#   '',
#   '10,470,265,000,000',
#   '18,151,405,000,000'],
#  ['3. Tiền gửi của khách hàng',
#   '1,195,391,576,000,000',
#   '1,197,150,901,000,000',
#   '1,243,468,472,000,000',
#   '1,281,487,916,000,000'],
#  ['4. Các công cụ tài chính phái sinh và nợ tài chính khác',
#   '19,457,000,000',
#   '120,079,000,000',
#   '',
#   ''],
#  ['5. Vốn tài trợ, ủy thác đầu tư, cho vay TCTD chịu rủi ro',
#   '5,485,000,000',
#   '4,385,000,000',
#   '3,298,000,000',
#   '2,186,000,000'],
#  ['6. Phát hành giấy tờ có giá',
#   '14,367,033,000,000',
#   '14,698,727,000,000',
#   '25,337,894,000,000',
#   '27,337,890,000,000'],
#  ['Thuế thu nhập doanh nghiệp', '', '', '', ''],
#  ['- Các khoản lãi, phí phải trả',
#   '10,960,439,000,000',
#   '12,813,118,000,000',
#   '12,485,332,000,000',
#   '15,749,162,000,000'],
#  ['- Các khoản phải trả và công nợ khác',
#   '25,960,600,000,000',
#   '22,775,636,000,000',
#   '95,079,105,000,000',
#   '59,693,542,000,000'],
#  ['- Dự phòng rủi ro khác', '', '', '', ''],
#  ['- Thuế TNDN phải trả', '', '', '', ''],
#  ['- Thuế TNDN hoãn lại phải trả', '', '', '', ''],
#  ['7. Các khoản nợ khác',
#   '36,921,039,000,000',
#   '35,588,754,000,000',
#   '107,564,437,000,000',
#   '75,442,704,000,000'],
#  ['Tổng nợ phải trả',
#   '1,479,402,030,000,000',
#   '1,521,274,777,000,000',
#   '1,676,199,767,000,000',
#   '1,701,772,932,000,000'],
#  ['8. Vốn và các quỹ',
#   '122,989,697,000,000',
#   '128,389,550,000,000',
#   '137,988,442,000,000',
#   '144,658,358,000,000'],
#  ['8.1. Vốn của TCTD',
#   '52,665,213,000,000',
#   '53,130,392,000,000',
#   '53,130,392,000,000',
#   '53,130,392,000,000'],
#  ['- Vốn điều lệ',
#   '47,325,166,000,000',
#   '47,325,166,000,000',
#   '47,325,166,000,000',
#   '47,325,166,000,000'],
#  ['- Vốn đầu tư XDCB', '', '', '4,995,389,000,000', ''],
#  ['- Thặng dư vốn cổ phần',
#   '4,995,389,000,000',
#   '4,995,389,000,000',
#   '',
#   '4,995,389,000,000'],
#  ['- Cổ phiếu quỹ (*)', '', '', '', ''],
#  ['- Cổ phiếu ưu đãi', '', '', '', ''],
#  ['- Vốn khác',
#   '344,658,000,000',
#   '809,837,000,000',
#   '809,837,000,000',
#   '809,837,000,000'],
#  ['8.2. Quỹ của TCTD',
#   '18,171,942,000,000',
#   '18,122,983,000,000',
#   '18,133,039,000,000',
#   '22,556,829,000,000'],
#  ['- Các quỹ dự trữ', '', '', '', ''],
#  ['8.3. Lợi nhuận chưa phân phối/Lỗ lũy kế',
#   '52,056,550,000,000',
#   '57,774,989,000,000',
#   '67,499,703,000,000',
#   '69,719,946,000,000'],
#  ['8.4. Lợi nhuận năm nay',
#   '-1,782,000,000',
#   '-741,021,000,000',
#   '-863,071,000,000',
#   '8,986,435,000,000'],
#  ['8.5. Lợi nhuận năm trước', '', '', '', '60,733,511,000,000'],
#  ['8.7. Chênh lệch đánh giá lại tài sản', '', '', '', ''],
#  ['8.6. Chênh lệch tỷ giá hối đoái',
#   '-1,782,000,000',
#   '-741,021,000,000',
#   '-863,071,000,000',
#   '-842,553,000,000'],
#  ['9. Lợi ích của cổ đông thiểu số',
#   '97,774,000,000',
#   '102,207,000,000',
#   '88,379,000,000',
#   '93,744,000,000'],
#  ['Tổng cộng nguồn vốn',
#   '1,602,391,727,000,000',
#   '1,649,664,327,000,000',
#   '1,814,188,209,000,000',
#   '1,846,431,290,000,000'],
#  ['Các khoản mục ghi nhớ', '', '', '', ''],
#  ['1. Thư tín dụng trả ngay', '', '', '', ''],
#  ['2. Thư tín dụng trả chậm', '', '', '', ''],
#  ['3. Bảo lãnh thanh toán', '', '', '', ''],
#  ['4. Bảo lãnh vay vốn', '', '', '', ''],
#  ['5. Bảo lãnh khác', '', '', '', ''],
#  ['6. Cam kết cho vay chưa giải ngân', '', '', '', ''],
#  ['7. Các cam kết khác', '', '', '', '']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(formatted_data)
df.head(20)
# Out:
#                                                     0  \
# 0                             VCB_BaoCaoLuyKe_6_Thang
# 1
# 2                                          I. TÀI SẢN
# 3        1. Tiền mặt và các khoản tương đương tại quỹ
# 4                                2. Tiền gửi tại NHNN
# 5               Tiền gửi thanh toán tại các TCTD khác
# 6   3. Tiền, vàng gửi tại các TCTD khác và cho vay...
# 7                        Tiền, vàng gửi tại TCTD khác
# 8                               Cho vay các TCTD khác
# 9               Dự phòng rủi ro cho vay các TCTD khác
# 10                              4. Cho vay khách hàng
# 11                                 Cho vay khách hàng
# 12                              - Cơ cấu nợ theo nhóm
# 13                                 + Nợ đủ tiêu chuẩn
# 14                                     + Nợ cần chú ý
# 15                               + Nợ dưới tiêu chuẩn
# 16                                      + Nợ nghi ngờ
# 17                           + Nợ có khả năng mất vốn
# 18                            - Cơ cấu nợ theo kỳ hạn
# 19                                         + Ngắn hạn
#
#                                1                             2  \
# 0                           None                          None
# 1   LK 6 tháng 2020(Đã soát xét)  LK 6 tháng 2021(Đã soát xét)
# 2
# 3             11,863,544,000,000            13,132,285,000,000
# 4             71,566,703,000,000            23,485,760,000,000
# 5
# 6            150,761,888,000,000           185,877,601,000,000
# 7            128,821,053,000,000           164,585,658,000,000
# 8             22,940,835,000,000            22,291,943,000,000
# 9             -1,000,000,000,000            -1,000,000,000,000
# 10           754,374,040,000,000           897,798,104,000,000
# 11           770,744,422,000,000           912,948,437,000,000
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
#
#                                3     4
# 0                           None  None
# 1   LK 6 tháng 2022(Đã soát xét)
# 2
# 3             15,097,807,000,000
# 4             28,813,961,000,000
# 5
# 6            255,536,982,000,000
# 7            206,455,463,000,000
# 8             50,081,519,000,000
# 9             -1,000,000,000,000
# 10         1,066,990,245,000,000
# 11         1,100,852,163,000,000
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
